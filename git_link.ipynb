# %%
# %cd "/content/drive/My Drive/Deep Learning"
# %pwd
# Out:
# /content/drive/My Drive/Deep Learning
# '/content/drive/My Drive/Deep Learning'

# %%
# !git remote remove origin
# !git branch -M master
# !git remote add origin git@github.com:emanant/deep_learning.git

# %%
# !git init
# !git config user.email "something.nothing01@gmail.com"
# !git config user.name "emanant"

# %%
# !git remote show origin
# Out:
# ...
# * remote origin
#   Fetch URL: git@github.com:emanant/deep_learning.git
#   Push  URL: git@github.com:emanant/deep_learning.git
#   HEAD branch: (unknown)

# %%
# !git stash
# !git pull origin master
# Out:
# Saved working directory and index state WIP on master: 946244d removing unnecessary files
# From github.com:emanant/deep_learning
#  * branch            master     -> FETCH_HEAD
# CONFLICT (modify/delete): git_link.ipynb deleted in a87f40e7de1d93e33d749907fcfe54906c818ecc and modified in HEAD. Version HEAD of git_link.ipynb left in tree.
# CONFLICT (modify/delete): .gitignore deleted in a87f40e7de1d93e33d749907fcfe54906c818ecc and modified in HEAD. Version HEAD of .gitignore left in tree.
# Automatic merge failed; fix conflicts and then commit the result.

# %%
# !git stash pop
# !git rm --cached
# !git add .

# %%
# !git commit -m "c"
# Out:
# [master ccad51b] removing unnecessary files

# %%
# !git push -u origin master
# Out:
# ...
# Counting objects: 7, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (7/7), 2.91 KiB | 425.00 KiB/s, done.
# Total 7 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 1 local object.
# To github.com:emanant/deep_learning.git
#    a87f40e..ccad51b  master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.

# %% [markdown]
# # Git SSH

# %%
# !ssh-keygen -t rsa -b 4096 -C "something.nothing01@gmail.com"

# %%
# !ls -al ~/.ssh

# %%
# !cat /root/.ssh/id_rsa.pub

# %%
# !cat /root/.ssh/id_rsa

# %%
# !ssh-keyscan github.com >> /root/.ssh/known_hosts
# !chmod 644 /root/.ssh/known_hosts

# !chmod 600 /root/.ssh/id_rsa
# !ssh -T git@github.com
