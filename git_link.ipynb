# %%
# %cd "/content/drive/My Drive/Deep Learning"
# %pwd
# Out:
# /content/drive/My Drive/Deep Learning
# '/content/drive/My Drive/Deep Learning'

# %%
# !git remote remove origin
# !git branch -M master
# !git remote add origin git@github.com:emanant/deep_learning.git

# %%
# !git init
# !git config user.email "something.nothing01@gmail.com"
# !git config user.name "emanant"

# %%
# !git add .

# %%
# !git commit -m "initial commit"
# Out:
# [master (root-commit) 13fe476] initial commit
#  16 files changed, 4782 insertions(+)
#  create mode 100644 .gitignore
#  create mode 100644 Lab1/Admission_Predict.csv
#  create mode 100644 Lab1/DL_Exp1_MTech_Linear_reg.pdf
#  create mode 100644 Lab1/DL_Lab1.ipynb
#  create mode 100644 Lab1/DL_Lab_1_ref.ipynb
#  create mode 100644 Lab1/EX1_201911027_Code.pdf
#  create mode 100644 Lab1/EX1_201911027_Report.pdf
#  create mode 100644 Lab1/heart.csv
#  create mode 100644 Lab2/DL_Exp2_MTech_ANN_Keras.docx.pdf
#  create mode 100644 Lab2/DL_Lab2_201911027.ipynb
#  create mode 100644 Lab2/DL_Lab2_201911027.pdf
#  create mode 100644 Lab2/datasets_11167_15520_train_Mobile.csv
#  create mode 100644 Lab2/heart.csv
#  create mode 100644 Lab3/DL_Lab3_201911027.ipynb
#  create mode 100644 git_link.ipynb
#  create mode 100644 readme.md

# %%
# !git push -u origin master
# Out:
# Host key verification failed.
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.

# %%
# !ls -al ~/.ssh
# Out:
# total 12
# drwx------ 2 root root 4096 Sep 25 13:08 .
# drwx------ 1 root root 4096 Sep 25 13:08 ..

# %% [markdown]
# # Git SSH

# %%
# !ssh-keygen -t rsa -b 4096 -C "something.nothing01@gmail.com"
# Out:
# Generating public/private rsa key pair.
# Enter file in which to save the key (/root/.ssh/id_rsa):
# Enter passphrase (empty for no passphrase):
# Enter same passphrase again:
# Your identification has been saved in /root/.ssh/id_rsa.
# Your public key has been saved in /root/.ssh/id_rsa.pub.
# The key fingerprint is:
# SHA256:P1r6fD4K+XAcAeORpN8qze3GjFgk/tkGN2qYlQJuXp8 something.nothing01@gmail.com
# The key's randomart image is:
# +---[RSA 4096]----+
# |       .=.       |
# |       o.+       |
# |      . . .      |
# |    . .... .     |
# |   . o oS.o      |
# |    o +o=*o.     |
# |   o ..XB@B.     |
# |    . +.E@*.o    |
# |       .o+*+..   |
# +----[SHA256]-----+

# %%
# !ls -al ~/.ssh
# Out:
# total 20
# drwx------ 2 root root 4096 Sep 25 13:21 .
# drwx------ 1 root root 4096 Sep 25 13:08 ..
# -rw------- 1 root root 3243 Sep 25 13:21 id_rsa
# -rw-r--r-- 1 root root  755 Sep 25 13:21 id_rsa.pub

# %%
# !cat /root/.ssh/id_rsa.pub
