# %%
# %cd "/content/drive/My Drive/Deep Learning"
# %pwd
# Out:
# /content/drive/My Drive/Deep Learning
# '/content/drive/My Drive/Deep Learning'

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/My Drive/Deep Learning/.git/

# %%
# !git add .

# %%
# !git commit -m "initial commit"
# Out:
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@d60484747525.(none)')

# %%
# !git config user.email "something.nothing01@gmail.com"
# !git config user.name "emanant"
